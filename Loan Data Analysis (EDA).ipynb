# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path="C:\\Users\\naidu\\Downloads\\train_ctrUa4K.csv"
loan_df=pd.read_csv(file_path)
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan_df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan_df.shape
# Out:
# (614, 13)

# %%
loan_df.size
# Out:
# 7982

# %%
loan_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
cat=[]
num=[]
dtypes=loan_df.dtypes
for i in dict(dtypes):
    if dtypes[i]=="O":
        cat.append(i)
        
    else:
        num.append(i)
cat=cat[1:]       
print("This data is catrogrical data type:", cat)
print('''***********************************''')
print("This data is numerical data type:",num)
# Out:
# This data is catrogrical data type: ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
# ***********************************
# This data is numerical data type: ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# %%
dtypes=dict(loan_df.dtypes)
dict1={i for i in dtypes if dtypes[i]=="O"}
dict2={i for i in dtypes if dtypes[i]!="O"}
print(dict1)
print(dict2)
# Out:
# {'Married', 'Gender', 'Property_Area', 'Dependents', 'Education', 'Loan_ID', 'Loan_Status', 'Self_Employed'}
# {'LoanAmount', 'Loan_Amount_Term', 'ApplicantIncome', 'Credit_History', 'CoapplicantIncome'}

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
for i in cat:                   
    loan_df[i].fillna(loan_df[i].mode()[0],inplace=True)

# %%
cat
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
for i in num:
    loan_df[i].fillna(loan_df[i].median(),inplace=True)

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
num
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
dict1=dict(loan_df['Gender'].value_counts())
gender=dict1.keys()
values=dict1.values()


gender1=pd.DataFrame(zip(gender,values),columns=['Gender','Count'])
gender1
# Out:
#    Gender  Count
# 0    Male    502
# 1  Female    112

# %%
name=loan_df['Gender'].value_counts()
count=name.plot(kind='bar')
count.bar_label(count.containers[0])
plt.show()

# %% [markdown]
# ## reading categorical columns

# %%
for i in cat:
    
    print(i,loan_df[i].unique())
# Out:
# Gender ['Male' 'Female']
# Married ['No' 'Yes']
# Dependents ['0' '1' '2' '3+']
# Education ['Graduate' 'Not Graduate']
# Self_Employed ['No' 'Yes']
# Property_Area ['Urban' 'Rural' 'Semiurban']
# Loan_Status ['Y' 'N']

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
plt.figure(figsize=(10,10))
for i in range(len(cat)):
    kn=loan_df[cat[i]].value_counts()
    i1=kn.keys()
    i2=kn.values
    file=pd.DataFrame(zip(i1,i2),columns=[cat[i],'count'])
    plt.subplot(3,3,i+1)
    plt.bar(file[cat[i]],file['count'],color=['green','orange'])
    
    plt.title('{} vs counts'. format(cat[i]))
    plt.xlabel(cat[i])
    plt.ylabel('count')
    plt.tight_layout(h_pad=0,w_pad=1)

# %%
keys=loan_df['Gender'].value_counts().keys()
values=loan_df['Gender'].value_counts(normalize=True).values*100
my=pd.DataFrame(zip(keys,values),columns=['Gender','Relative Frequency'])
my
# Out:
#    Gender  Relative Frequency
# 0    Male           81.758958
# 1  Female           18.241042

# %%
plt.figure(figsize=[8,8])
for i in range(len(cat)):
    kn=loan_df[cat[i]].value_counts()
    i1=kn.keys()
    i2=kn.values
    file=pd.DataFrame(zip(i1,i2),columns=[cat[i],'count'])
    plt.subplot(3,3,i+1)
    plt.pie(file['count'],labels=file[cat[i]],autopct="%0.2f%%")
    plt.title('{} vs counts'. format(cat[i]))
    #plt.xlabel(cat[i])
    #plt.ylabel('count')
    #plt.tight_layout(h_pad=0,w_pad=1)

# %% [markdown]
# ## Numerical analysis

# %%
hist=loan_df.describe()
hist
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  145.752443        342.410423
# std        6109.041673        2926.248369   84.107233         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  128.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
for i in range(len(num)):
    plt.subplot(2,3,i+1)
    plt.hist(loan_df[num[i]],bins=40)
    plt.title('{}'. format(num[i]))
    plt.tight_layout(h_pad=0,w_pad=1)

# %%
plt.figure(figsize=(7,5))
for i in range(len(num)):
    plt.subplot(2,3,i+1)
    plt.boxplot(loan_df[num[i]],vert=False)
    plt.title('{}'. format(num[i]))
    plt.tight_layout(h_pad=0,w_pad=1)

# %%
plt.figure(figsize=(8,8))
for i in num:
    q1=np.percentile(loan_df[i],25)
    q2=np.percentile(loan_df[i],50)
    q3=np.percentile(loan_df[i],75)
    IQR=q3-q1
    UB=q3+1.5*IQR
    LB=q1-1.5*IQR
    con1=loan_df[i]<UB
    con2=loan_df[i]>LB
    con=con1|con2
    non_out=loan_df[con1|con2]
    per_outiers=100-(len(loan_df[loan_df[i].between(LB,UB)])/len(loan_df))*100
    na=round(per_outiers,2)
    data=print(i,':',round(per_outiers,2))
   
    plt.bar(i,na)
    plt.title("outliers data percentage")
    plt.xlabel("Numerical data")
    plt.ylabel("percentage")
    plt.tight_layout(h_pad=5,w_pad=3)
# Out:
# ApplicantIncome : 8.14
# CoapplicantIncome : 2.93
# LoanAmount : 6.68
# Loan_Amount_Term : 14.33
# Credit_History : 14.5

# %% [markdown]
# ## ApplicantIncome

# %% [markdown]
# ## Finding the outliers of every numerical columns

# %%
loan_df['ApplicantIncome'].describe()
# Out:
# count      614.000000
# mean      5403.459283
# std       6109.041673
# min        150.000000
# 25%       2877.500000
# 50%       3812.500000
# 75%       5795.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# #### let us find the outliers using the boxplot

# %%
q1=np.percentile(loan_df['ApplicantIncome'],25)
q2=np.percentile(loan_df['ApplicantIncome'],50)
q3=np.percentile(loan_df['ApplicantIncome'],75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
con1=loan_df['ApplicantIncome']>UB
con2=loan_df['ApplicantIncome']<LB
con=con1|con2
len(loan_df['ApplicantIncome'][con])
# Out:
# 50

# %% [markdown]
# #### So we have to remove the outliers in data (50)

# %% [markdown]
# ##### mrthod:-1

# %%
q1=np.percentile(loan_df['ApplicantIncome'],25)
q2=np.percentile(loan_df['ApplicantIncome'],50)
q3=np.percentile(loan_df['ApplicantIncome'],75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
con1=loan_df['ApplicantIncome']<UB
con2=loan_df['ApplicantIncome']>LB
Data=loan_df['ApplicantIncome'][con1&con2]
pd.DataFrame(Data)
# Out:
#      ApplicantIncome
# 0               5849
# 1               4583
# 2               3000
# 3               2583
# 4               6000
# ..               ...
# 609             2900
# 610             4106
# 611             8072
# 612             7583
# 613             4583
#
# [564 rows x 1 columns]

# %% [markdown]
# #### Histogram and boxplot analysis of applicantincome columns let us try impuctiing the median value

# %%
l1=[]
q1=np.percentile(loan_df['ApplicantIncome'],25)
q2=np.percentile(loan_df['ApplicantIncome'],50)
q3=np.percentile(loan_df['ApplicantIncome'],75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
for i in loan_df['ApplicantIncome']:
    if i>UB or i<LB:
        l1.append(q2)
    else:
        l1.append(i)
        
    API=pd.DataFrame(l1,columns=['ApplicantIncome'])
API
# Out:
#      ApplicantIncome
# 0             5849.0
# 1             4583.0
# 2             3000.0
# 3             2583.0
# 4             6000.0
# ..               ...
# 609           2900.0
# 610           4106.0
# 611           8072.0
# 612           7583.0
# 613           4583.0
#
# [614 rows x 1 columns]

# %% [markdown]
# #### compare the original_outliers data and non_outliers data in hist ,boxplot

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title('outliers data of ApplicantIncome')
plt.hist(loan_df['ApplicantIncome'],bins=40)
plt.subplot(2,2,2)
plt.title("non_outliers of ApplicantIncome ")
plt.hist(API,bins=40)
plt.subplot(2,2,3)
plt.title('outliers data of ApplicantIncome')
plt.boxplot(loan_df['ApplicantIncome'],vert=False)
plt.subplot(2,2,4)
plt.title("non_outliers of ApplicantIncome ")
plt.boxplot(API,vert=False)
plt.show()

# %% [markdown]
# #### Now we will to check the Emperical Rule of the new column of ApplicantIncome

# %%
l1=[]
q1=np.percentile(loan_df['ApplicantIncome'],25)
q2=np.percentile(loan_df['ApplicantIncome'],50)
q3=np.percentile(loan_df['ApplicantIncome'],75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
for i in loan_df['ApplicantIncome']:
    if i>UB or i<LB:
        l1.append(q2)
    else:
        l1.append(i)
        
    loan_df["new_ApplicantIncome"]=pd.DataFrame(l1,columns=['ApplicantIncome'])

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# #### Now we start the emprical rule`

# %%
## 68% of data should lie between
68*614/100
# Out:
# 417.52

# %%
x1=loan_df['new_ApplicantIncome'].mean()
x2=loan_df['new_ApplicantIncome'].std()
a=x1-1*x2
b=x1+1*x2
con1=loan_df['new_ApplicantIncome']>a
con2=loan_df['new_ApplicantIncome']<b
len(loan_df['new_ApplicantIncome'][con1 & con2])
# Out:
# 455

# %%
### 95% of the data should lie between
95*614/100
# Out:
# 583.3

# %%
x1=loan_df['new_ApplicantIncome'].mean()
x2=loan_df['new_ApplicantIncome'].std()
a=x1-2*x2
b=x1+2*x2
con1=loan_df['new_ApplicantIncome']>a
con2=loan_df['new_ApplicantIncome']<b
len(loan_df['new_ApplicantIncome'][con1 & con2])
# Out:
# 575

# %%
### 99.7%
99.7*614/100
# Out:
# 612.158

# %%
x1=loan_df['new_ApplicantIncome'].mean()
x2=loan_df['new_ApplicantIncome'].std()
a=x1-3*x2
b=x1+3*x2
con1=loan_df['new_ApplicantIncome']>a
con2=loan_df['new_ApplicantIncome']<b
len(loan_df['new_ApplicantIncome'][con1 & con2])
# Out:
# 606

# %% [markdown]
# ## Normalization  and Standardization

# %%
from sklearn.preprocessing import MinMaxScaler
mss=MinMaxScaler()
loan_df['ApplicantIncome_mss']=mss.fit_transform(loan_df[['ApplicantIncome']])
print(loan_df['ApplicantIncome_mss'].min())
print(loan_df['ApplicantIncome_mss'].max())
# Out:
# 0.0
# 1.0000000000000002

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
loan_df['ApplicantIncome_ss']=ss.fit_transform(loan_df[['ApplicantIncome']])
print(loan_df['ApplicantIncome_ss'].min())
print(loan_df['ApplicantIncome_ss'].max())
# Out:
# -0.8606493225189494
# 12.38462278717314

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ## Now we Draw the boxplot

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title('ApplicantIncome')
plt.boxplot(loan_df["ApplicantIncome"],vert=False)
plt.subplot(2,2,2)
plt.title("Applicantincome with Normlization")
plt.boxplot(loan_df['ApplicantIncome_mss'],vert=False)
plt.subplot(2,2,3)
plt.title("ApplicantIncome")
plt.boxplot(loan_df["ApplicantIncome"],vert=False)
plt.subplot(2,2,4)
plt.title("Applicantincome with standardization")
plt.boxplot(loan_df['ApplicantIncome_ss'],vert=False)
plt.show()

# %%
num
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %% [markdown]
# ## CoapplicantIncome

# %%
 loan_df['CoapplicantIncome'].describe()
# Out:
# count      614.000000
# mean      1621.245798
# std       2926.248369
# min          0.000000
# 25%          0.000000
# 50%       1188.500000
# 75%       2297.250000
# max      41667.000000
# Name: CoapplicantIncome, dtype: float64

# %%
q1=np.percentile(loan_df['CoapplicantIncome'],25)
q2=np.percentile(loan_df['CoapplicantIncome'],50)
q3=np.percentile(loan_df['CoapplicantIncome'],75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
co1=loan_df['CoapplicantIncome']>UB
co2=loan_df['CoapplicantIncome']<LB
co=co1|co2
len(loan_df['CoapplicantIncome'][co])
# Out:
# 18

# %%
## we try to remove outliers data

q1=np.percentile(loan_df['CoapplicantIncome'],25)
q2=np.percentile(loan_df['CoapplicantIncome'],50)
q3=np.percentile(loan_df['CoapplicantIncome'],75)
IQR=q3-q1
UB1=q3+1.5*IQR
LB1=q1-1.5*IQR
co11=loan_df['CoapplicantIncome']<UB1
co21=loan_df['CoapplicantIncome']>LB1
ko=loan_df['CoapplicantIncome'][co11&co21]
pd.DataFrame(ko)
# Out:
#      CoapplicantIncome
# 0                  0.0
# 1               1508.0
# 2                  0.0
# 3               2358.0
# 4                  0.0
# ..                 ...
# 609                0.0
# 610                0.0
# 611              240.0
# 612                0.0
# 613                0.0
#
# [596 rows x 1 columns]

# %%
## we are analysis the data the hist and boxplot
## let impucting the median value

l1=[]
q1=np.percentile(loan_df['CoapplicantIncome'],25)
q2=np.percentile(loan_df['CoapplicantIncome'],50)
q3=np.percentile(loan_df['CoapplicantIncome'],75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
for i in loan_df['CoapplicantIncome']:
    if i>UB or i<LB:
        l1.append(q2)
    else:
        l1.append(i)
CI=pd.DataFrame(l1,columns=['CoapplicantIncome'])
CI
# Out:
#      CoapplicantIncome
# 0                  0.0
# 1               1508.0
# 2                  0.0
# 3               2358.0
# 4                  0.0
# ..                 ...
# 609                0.0
# 610                0.0
# 611              240.0
# 612                0.0
# 613                0.0
#
# [614 rows x 1 columns]

# %%
## compare the original outliers and non _outloers  in hist and box

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("outliers_data of CoapplicantIncome ")
plt.hist(loan_df['CoapplicantIncome'],bins=40)
plt.subplot(2,2,2)
plt.title('non_outliers data of CoapplicantIncome' )
plt.hist(CI,bins=40)
plt.subplot(2,2,3)
plt.title("outliers_data of CoapplicantIncome ")
plt.boxplot(loan_df['CoapplicantIncome'],vert=False)
plt.subplot(2,2,4)
plt.title('non_outliers data of CoapplicantIncome' )
plt.boxplot(CI,vert=False)
plt.show()

# %%
## now new columns of  CoapplicantIncome

# %%
l1=[]
q1=np.percentile(loan_df['CoapplicantIncome'],25)
q2=np.percentile(loan_df['CoapplicantIncome'],50)
q3=np.percentile(loan_df['CoapplicantIncome'],75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
for i in loan_df['CoapplicantIncome']:
    if i>UB or i<LB:
        l1.append(q2)
    else:
        l1.append(i)
loan_df['new_CoapplicantIncome']=pd.DataFrame(l1,columns=['CoapplicantIncome'])

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ### calculte the Emprical rule

# %%
68*614/100
# Out:
# 417.52

# %%
x2=loan_df['CoapplicantIncome'].mean()
x3=loan_df['CoapplicantIncome'].std()
a=x2-1*x3
b=x2+1*x3
co1=loan_df['CoapplicantIncome']>a
co2=loan_df['CoapplicantIncome']<b
len(loan_df['CoapplicantIncome'][co1&co2])
# Out:
# 575

# %%
95*614/100
# Out:
# 583.3

# %%
x2=loan_df['CoapplicantIncome'].mean()
x3=loan_df['CoapplicantIncome'].std()
a=x2-2*x3
b=x2+2*x3
co1=loan_df['CoapplicantIncome']>a
co2=loan_df['CoapplicantIncome']<b
len(loan_df['CoapplicantIncome'][co1&co2])
# Out:
# 603

# %%
99.7*614/100
# Out:
# 612.158

# %%
x2=loan_df['CoapplicantIncome'].mean()
x3=loan_df['CoapplicantIncome'].std()
a=x2-3*x3
b=x2+3*x3
co1=loan_df['CoapplicantIncome']>a
co2=loan_df['CoapplicantIncome']<b
len(loan_df['CoapplicantIncome'][co1&co2])
# Out:
# 608

# %%
### check the normlization


from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
loan_df['CoapplicantIncome_m']=m.fit_transform(loan_df[['CoapplicantIncome']])
print(loan_df['CoapplicantIncome_m'].min())
print(loan_df['CoapplicantIncome_m'].max())
# Out:
# 0.0
# 1.0

# %%
## stabdardization

from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
loan_df["new_CoapplicantIncome_SS"]=SS.fit_transform(loan_df[["CoapplicantIncome"]])
print(loan_df["new_CoapplicantIncome_SS"].min())
print(loan_df["new_CoapplicantIncome_SS"].max())
# Out:
# -0.5544873301529852
# 13.696173250494041

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
## now draw the boxplot

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("CoapplicantIncome")
plt.boxplot(loan_df['CoapplicantIncome'],vert=False)
plt.subplot(2,2,2)
plt.title("CoapplicantIncome with normlizatiion")
plt.boxplot(loan_df['CoapplicantIncome_m'],vert=False)
plt.subplot(2,2,3)
plt.title("CoapplicantIncome")
plt.boxplot(loan_df['CoapplicantIncome'],vert=False)
plt.subplot(2,2,4)
plt.title("CoapplicantIncome with standardization")
plt.boxplot(loan_df['new_CoapplicantIncome_SS'],vert=False)
plt.show()

# %%
num
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %% [markdown]
# ### LoanAmount

# %%
loan_df['LoanAmount'].describe()
# Out:
# count    614.000000
# mean     145.752443
# std       84.107233
# min        9.000000
# 25%      100.250000
# 50%      128.000000
# 75%      164.750000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %%
q1=np.percentile(loan_df['LoanAmount'],25)
q2=np.percentile(loan_df['LoanAmount'],50)
q3=np.percentile(loan_df['LoanAmount'],75)
IQR=q3-q1
ub=q3+1.5*IQR
lb=q1-1.5*IQR
con1=loan_df['LoanAmount']>ub
con2=loan_df['LoanAmount']<lb
con=con1|con2
len(loan_df['LoanAmount'][con])
# Out:
# 41

# %%
q1=np.percentile(loan_df['LoanAmount'],25)
q2=np.percentile(loan_df['LoanAmount'],50)
q3=np.percentile(loan_df['LoanAmount'],75)
IQR=q3-q1
ub=q3+1.5*IQR
lb=q1-1.5*IQR
con1=loan_df['LoanAmount']<ub
con2=loan_df['LoanAmount']>lb
kn=loan_df['LoanAmount'][con1&con2]
pd.DataFrame(kn)
# Out:
#      LoanAmount
# 0         128.0
# 1         128.0
# 2          66.0
# 3         120.0
# 4         141.0
# ..          ...
# 609        71.0
# 610        40.0
# 611       253.0
# 612       187.0
# 613       133.0
#
# [573 rows x 1 columns]

# %%
l1=[]
q1=np.percentile(loan_df['LoanAmount'],25)
q2=np.percentile(loan_df['LoanAmount'],50)
q3=np.percentile(loan_df['LoanAmount'],75)
IQR=q3-q1
ub=q3+1.5*IQR
lb=q1-1.5*IQR
for i in loan_df['LoanAmount']:
    if i>ub or i<lb:
        l1.append(q2)
    else:
        l1.append(i)
        
LA=pd.DataFrame(l1,columns=['LoanAmount'])
LA
# Out:
#      LoanAmount
# 0         128.0
# 1         128.0
# 2          66.0
# 3         120.0
# 4         141.0
# ..          ...
# 609        71.0
# 610        40.0
# 611       253.0
# 612       187.0
# 613       133.0
#
# [614 rows x 1 columns]

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title('out_liers of LoanAmount')
plt.hist(loan_df['LoanAmount'],bins=40)
plt.subplot(2,2,2)
plt.title('non_outliers of LoanAmount')
plt.hist(LA,bins=40)
plt.subplot(2,2,3)
plt.title('out_liers of LoanAmount')
plt.boxplot(loan_df['LoanAmount'],vert=False)
plt.subplot(2,2,4)
plt.title('non_outliers of LoanAmount')
plt.boxplot(LA,vert=False)
plt.show()

# %%
## New columns

# %%
l1=[]
q1=np.percentile(loan_df['LoanAmount'],25)
q2=np.percentile(loan_df['LoanAmount'],50)
q3=np.percentile(loan_df['LoanAmount'],75)
IQR=q3-q1
ub=q3+1.5*IQR
lb=q1-1.5*IQR
for i in loan_df['LoanAmount']:
    if i>ub or i<lb:
        l1.append(q2)
    else:
        l1.append(i)
        
loan_df["new_LoanAmount"]=pd.DataFrame(l1,columns=['LoanAmount'])

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
## emprical rule

# %%
68*614/100
# Out:
# 417.52

# %%
x1=loan_df['new_LoanAmount'].mean()
x2=loan_df['new_LoanAmount'].std()
a=x1-1*x2
b=x1+1*x2
con1=loan_df['new_LoanAmount']>a
con2=loan_df['new_LoanAmount']<b
len(loan_df['new_LoanAmount'][con1&con2])
# Out:
# 434

# %%
95*614/100
# Out:
# 583.3

# %%
x1=loan_df['new_LoanAmount'].mean()
x2=loan_df['new_LoanAmount'].std()
a=x1-2*x2
b=x1+2*x2
con1=loan_df['new_LoanAmount']>a
con2=loan_df['new_LoanAmount']<b
len(loan_df['new_LoanAmount'][con1&con2])
# Out:
# 580

# %%
99.7*614/100
# Out:
# 612.158

# %%
x1=loan_df['new_LoanAmount'].mean()
x2=loan_df['new_LoanAmount'].std()
a=x1-3*x2
b=x1+3*x2
con1=loan_df['new_LoanAmount']>a
con2=loan_df['new_LoanAmount']<b
len(loan_df['new_LoanAmount'][con1&con2])
# Out:
# 614

# %% [raw]
# ### Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
mmn=MinMaxScaler()
loan_df['LoanAmount_mmn']=mmn.fit_transform(loan_df[['LoanAmount']])
print(loan_df['LoanAmount_mmn'].min())
print(loan_df['LoanAmount_mmn'].max())
# Out:
# 0.0
# 1.0

# %%
### standardization

# %%
from sklearn.preprocessing import StandardScaler
ss1=StandardScaler()
loan_df['LoanAmount_ss1']=ss1.fit_transform(loan_df[['LoanAmount']])
print(loan_df['LoanAmount_ss1'].min())
print(loan_df['LoanAmount_ss1'].max())
# Out:
# -1.627255298188799
# 6.59514560674599

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title('LoanAmount')
plt.boxplot(loan_df['LoanAmount'],vert=False)
plt.subplot(2,2,2)
plt.title('LoanAmount with Normlization')
plt.boxplot(loan_df['LoanAmount_mmn'],vert=False)
plt.subplot(2,2,3)
plt.title('LoanAmount')
plt.boxplot(loan_df['LoanAmount'],vert=False)
plt.subplot(2,2,4)
plt.title('LoanAmount with Standardization')
plt.boxplot(loan_df['LoanAmount_ss1'],vert=False)
plt.show()

# %%
num
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %% [markdown]
# ## Bivarient and multivarint analysis

# %%
## let us do the 2 different columns and 3 different columns

# %%
biv=pd.crosstab(loan_df["Education"],loan_df['Loan_Status'])
biv
# Out:
# Loan_Status     N    Y
# Education
# Graduate      140  340
# Not Graduate   52   82

# %%
bivdata=pd.crosstab(loan_df["Education"],loan_df['Loan_Status'])
bivdata.plot(kind="bar")
plt.show()

# %%
bivdata=pd.crosstab(loan_df["Gender"],loan_df['Loan_Status'])
bivdata.plot(kind="bar")
plt.show()

# %%
bivdata=pd.crosstab(loan_df["Married"],loan_df['Loan_Status'])
bivdata.plot(kind="bar")
plt.show()

# %%
bivdata=pd.crosstab(loan_df['Dependents'],loan_df['Loan_Status'])  
bivdata.plot(kind="bar")
plt.show()

# %%
bivdata=pd.crosstab(loan_df['Self_Employed'],loan_df['Loan_Status'])  
bivdata.plot(kind="bar")
plt.show()

# %%
#plt.figure(figsize=(10,10))
bivdata=pd.crosstab(loan_df['Loan_Amount_Term'],loan_df['Loan_Status'])  
bivdata.plot(kind="bar")
plt.tight_layout(h_pad=10,w_pad=30)
plt.show()

# %%
bivdata=pd.crosstab(loan_df['Property_Area'],loan_df['Loan_Status'])  
bivdata.plot(kind="bar")
plt.show()

# %%
bivdata=pd.crosstab(loan_df['Property_Area'],[loan_df['Loan_Status'],loan_df['Gender']])  
#print(bivdata)
bivdata.plot(kind='bar')
bivdata
# Out:
# Loan_Status        N           Y
# Gender        Female Male Female Male
# Property_Area
# Rural             10   59     14   96
# Semiurban         13   41     42  137
# Urban             14   55     19  114

# %% [markdown]
# ### mutlivarient ananlysis

# %%
loan_df['LoanAmount']
# Out:
# 0      128.0
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %% [markdown]
# ## Scatter_plot

# %%
plt.scatter(loan_df['ApplicantIncome'],loan_df["CoapplicantIncome"])

# %%
plt.scatter(loan_df['ApplicantIncome'],loan_df["LoanAmount"])

# %%
x=loan_df['ApplicantIncome']
y=loan_df['LoanAmount']
plt.scatter(x,y,color='green')

x_sort = np.sort(x)
#y_sort = y[np.argsort(x)]
y_sort = np.sort(y)#[np.argsort(x)]
plt.plot(x_sort, y_sort)

# %%
corr_data=loan_df.corr(numeric_only=True)
corr_data
# Out:
#                           ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome                  1.000000          -0.116605    0.565181
# CoapplicantIncome               -0.116605           1.000000    0.189218
# LoanAmount                       0.565181           0.189218    1.000000
# Loan_Amount_Term                -0.046531          -0.059383    0.036960
# Credit_History                  -0.018615           0.011134   -0.000607
# new_ApplicantIncome              0.269446          -0.171521    0.293880
# ApplicantIncome_mss              1.000000          -0.116605    0.565181
# ApplicantIncome_ss               1.000000          -0.116605    0.565181
# new_CoapplicantIncome           -0.175488           0.484389    0.104426
# CoapplicantIncome_m             -0.116605           1.000000    0.189218
# new_CoapplicantIncome_SS        -0.116605           1.000000    0.189218
# new_LoanAmount                   0.186346           0.131401    0.530574
# ...

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(corr_data,annot=True)
# Out:
# <Axes: >

# %%
loan=pd.read_csv(file_path)
loan
corr_data=loan.corr(numeric_only=True)
corr_data
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %%
sns.heatmap(corr_data,annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(loan_df['LoanAmount'],loan_df['ApplicantIncome'],color='blue')

# %%
x=loan_df['LoanAmount']
y=loan_df['ApplicantIncome']
plt.scatter(x,y,color='red')

x_sort = np.sort(x)
y_sort = np.sort(y)#[np.argsort(x)]
plt.plot(x_sort, y_sort)

# %%
corr_data.max()[:2]
# Out:
# ApplicantIncome      1.0
# CoapplicantIncome    1.0
# dtype: float64

# %%
corr_data.min()[:2]
# Out:
# ApplicantIncome     -0.116605
# CoapplicantIncome   -0.116605
# dtype: float64

# %%
### categorial data to numerical data

# %%
loan_df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
k=loan_df['Gender']=='Male'
loan_df['Gender']=np.where(k,0,1)
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002       0      No          0      Graduate            No
# 1    LP001003       0     Yes          1      Graduate            No
# 2    LP001005       0     Yes          0      Graduate           Yes
# 3    LP001006       0     Yes          0  Not Graduate            No
# 4    LP001008       0      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978       1      No          0      Graduate            No
# 610  LP002979       0     Yes         3+      Graduate            No
# 611  LP002983       0     Yes          1      Graduate            No
# 612  LP002984       0     Yes          2      Graduate            No
# 613  LP002990       1      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# ...

# %%
k=loan_df['Married']=='Yes'
loan_df['Married']=np.where(k,0,1)
loan_df
# Out:
#       Loan_ID  Gender  Married Dependents     Education Self_Employed  \
# 0    LP001002       0        1          0      Graduate            No
# 1    LP001003       0        0          1      Graduate            No
# 2    LP001005       0        0          0      Graduate           Yes
# 3    LP001006       0        0          0  Not Graduate            No
# 4    LP001008       0        1          0      Graduate            No
# ..        ...     ...      ...        ...           ...           ...
# 609  LP002978       1        1          0      Graduate            No
# 610  LP002979       0        0         3+      Graduate            No
# 611  LP002983       0        0          1      Graduate            No
# 612  LP002984       0        0          2      Graduate            No
# 613  LP002990       1        1          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# ...

# %%
loan_df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
k=loan_df['Education']=='Graduate'
loan_df['Education']=np.where(k,0,1)
loan_df
# Out:
#       Loan_ID  Gender  Married Dependents  Education Self_Employed  \
# 0    LP001002       0        1          0          0            No
# 1    LP001003       0        0          1          0            No
# 2    LP001005       0        0          0          0           Yes
# 3    LP001006       0        0          0          1            No
# 4    LP001008       0        1          0          0            No
# ..        ...     ...      ...        ...        ...           ...
# 609  LP002978       1        1          0          0            No
# 610  LP002979       0        0         3+          0            No
# 611  LP002983       0        0          1          0            No
# 612  LP002984       0        0          2          0            No
# 613  LP002990       1        1          0          0           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# 0               5849                0.0       128.0             360.0  ...
# ...

# %%
k=loan_df['Self_Employed']=='No'
loan_df['Self_Employed']=np.where(k,0,1)
loan_df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       0        1          0          0              0
# 1    LP001003       0        0          1          0              0
# 2    LP001005       0        0          0          0              1
# 3    LP001006       0        0          0          1              0
# 4    LP001008       0        1          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       1        1          0          0              0
# 610  LP002979       0        0         3+          0              0
# 611  LP002983       0        0          1          0              0
# 612  LP002984       0        0          2          0              0
# 613  LP002990       1        1          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# ...

# %%
loan_df.dtypes
# Out:
# Loan_ID                      object
# Gender                        int32
# Married                       int32
# Dependents                   object
# Education                     int32
# Self_Employed                 int32
# ApplicantIncome               int64
# CoapplicantIncome           float64
# LoanAmount                  float64
# Loan_Amount_Term            float64
# Credit_History              float64
# Property_Area                object
# Loan_Status                  object
# new_ApplicantIncome         float64
# ApplicantIncome_mss         float64
# ApplicantIncome_ss          float64
# new_CoapplicantIncome       float64
# CoapplicantIncome_m         float64
# new_CoapplicantIncome_SS    float64
# new_LoanAmount              float64
# LoanAmount_mmn              float64
# LoanAmount_ss1              float64
# dtype: object

# %%
k=loan_df['Loan_Status']=='Yes'
loan_df['Loan_Status']=np.where(k,0,1)
loan_df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       0        1          0          0              0
# 1    LP001003       0        0          1          0              0
# 2    LP001005       0        0          0          0              1
# 3    LP001006       0        0          0          1              0
# 4    LP001008       0        1          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       1        1          0          0              0
# 610  LP002979       0        0         3+          0              0
# 611  LP002983       0        0          1          0              0
# 612  LP002984       0        0          2          0              0
# 613  LP002990       1        1          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
loan_df['Dependents']=le.fit_transform(loan_df['Dependents'])
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       0        1           0          0              0
# 1    LP001003       0        0           1          0              0
# 2    LP001005       0        0           0          0              1
# 3    LP001006       0        0           0          1              0
# 4    LP001008       0        1           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       1        1           0          0              0
# 610  LP002979       0        0           3          0              0
# 611  LP002983       0        0           1          0              0
# 612  LP002984       0        0           2          0              0
# 613  LP002990       1        1           0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
loan_df['Property_Area']=le.fit_transform(loan_df['Property_Area'])
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       0        1           0          0              0
# 1    LP001003       0        0           1          0              0
# 2    LP001005       0        0           0          0              1
# 3    LP001006       0        0           0          1              0
# 4    LP001008       0        1           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       1        1           0          0              0
# 610  LP002979       0        0           3          0              0
# 611  LP002983       0        0           1          0              0
# 612  LP002984       0        0           2          0              0
# 613  LP002990       1        1           0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# ...

# %%
Complete Following topics
- EDA Part-1:
   
     - shape/size
       
     - columns/dtypes
   
     - head/tail
       
     - take/loc/iloc
   
     - isnull/len

    - missing values analysis
       
- EDA Part-2 Categorical data analysis

     - How to read a column
   
     - unique/nunique
       
     - value counts
   
     - we created a frequncy table by our own skill
       
     - bar chart
   
     - pie chart
       
       
- EDA Part-3  Numerical data analysis
 
     - How to read a column
       
     - statistical measurements
   
     - mean/median/count/max/min/std/25/50/75
       
     - describe function
   
     - using numpy we draw measurements
       
     - Histogram
   
     - we checked the empiricle rule
       
       
- EDA PART-4 Outlier analysis

     - We draw box plot
   
     - we implemented how to find outlier
       
     - we remove the outliers
   
     - we imputed with median
       
     - np.where
   

- EDA PART-5: Bi variate and multivariate analysis
   
    - we draw two cat columns analysis
   
    - we implemented by our own skill
   
    - pd.crosstab
   
    - draw the plots
   
    - we repeated multiple columns
   
    - for two numerical columns plt.scatter
   
    - correlation data.corr
   
    - matrix
   

    - heatmap


EDA PART-6: Categorical to Numerical

  - Lable encoder

  - One hot encoder

EDA PART-7: Normalization and Standardization

   - MinMaxScalar

   - Z score
# Out:
#   File <tokenize>:14
#     - missing values analysis
#     ^
# IndentationError: unindent does not match any outer indentation level
